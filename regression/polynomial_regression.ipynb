# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.linear_model as sklin
import sklearn.model_selection as skms
import sklearn.metrics as skmet
import sklearn.preprocessing as skpre

# %%
dataset = pd.read_csv('../data/SampleRegressionDataset.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = skms.train_test_split(X, y, test_size=0.2)

# %%
poly_reg = skpre.PolynomialFeatures(degree = 2)
X_train_poly = poly_reg.fit_transform(X_train)

regressor = sklin.LinearRegression()
regressor.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
X_test_poly = poly_reg.fit_transform(X_test)
y_pred = regressor.predict(X_test_poly)
np.set_printoptions(precision=2)
print(y_pred)
# Out:
# [489.46 459.82 444.55 ... 470.16 466.02 436.01]

# %%
skmet.r2_score(y_pred=y_pred, y_true = y_test)
# Out:
# 0.9376387033464197

# %%
plt.scatter(y_test, y_pred, color="blue")
plt.title("Actual vs Predicted")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
plt.scatter(y_test, y_pred-y_test, color="red")
plt.title("Actual vs Error")
plt.xlabel("Actual")
plt.ylabel("Error (Pred - Act)")
plt.show()
